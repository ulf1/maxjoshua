# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('..')

import numpy as np
import maxjoshua as mh

# %%
np.random.seed(42)
X = np.random.random((7,2)) > 0.5
X
# Out:
# array([[False,  True],
#        [ True,  True],
#        [False, False],
#        [False,  True],
#        [ True,  True],
#        [False,  True],
#        [ True, False]])

# %%
negate = (1, 0)
Y = mh.negate_bool_features(X, negate)
Y
# Out:
# array([[ True,  True],
#        [False,  True],
#        [ True, False],
#        [ True,  True],
#        [False,  True],
#        [ True,  True],
#        [False, False]])
